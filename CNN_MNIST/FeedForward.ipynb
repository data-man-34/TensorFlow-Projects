# %%
import tensorflow as tf
import numpy as np

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("mnist/", one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-2-a8a244d9335a>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting mnist/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting mnist/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting mnist/t10k-images-idx3-ubyte.gz
# Extracting mnist/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: __init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
batch_size = 100
learning_rate = 0.005
max_steps = 10000


images_placeholder = tf.placeholder(tf.float32, shape=[None, 784])
labels_placeholder = tf.placeholder(tf.int64, shape=[None])

# Define variables (these are the values we want to optimize)
weights = tf.Variable(tf.zeros([784, 10]))
biases = tf.Variable(tf.zeros([10]))

# Define the classifier's result
logits = tf.matmul(images_placeholder, weights) + biases

# Define the loss function
loss = tf.reduce_mean(tf.nn.sparse_softmax_cross_entropy_with_logits(logits=logits,
  labels=labels_placeholder))

# Define the training operation
train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

# Operation comparing prediction with true label
correct_prediction = tf.equal(tf.argmax(logits, 1), labels_placeholder)

# Operation calculating the accuracy of our predictions
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

with tf.Session() as sess:
    # Initialize variables
    sess.run(tf.global_variables_initializer())

    # Repeat max_steps times
    for i in range(max_steps):

        # Generate input data batch
        images_batch, labels_batch = mnist.train.next_batch(batch_size)
        labels_batch = labels_batch.argmax(axis=1)

        # Periodically print out the model's current accuracy
        if i % 100 == 0:
            train_accuracy = sess.run(accuracy, feed_dict={
                images_placeholder: images_batch, labels_placeholder: labels_batch})
            print('Step {:5d}: training accuracy {:g}'.format(i, train_accuracy))

        # Perform a single training step
        sess.run(train_step, feed_dict={images_placeholder: images_batch,
                                        labels_placeholder: labels_batch})

    # After finishing the training, evaluate on the test set
    test_accuracy = sess.run(accuracy, feed_dict={
        images_placeholder: mnist.test.images,
        labels_placeholder: mnist.test.labels.argmax(axis=1)})
    print('Test accuracy {:g}'.format(test_accuracy))
# Out:
# Step     0: training accuracy 0.13
# Step   100: training accuracy 0.74
# Step   200: training accuracy 0.73
# Step   300: training accuracy 0.77
# Step   400: training accuracy 0.83
# Step   500: training accuracy 0.81
# Step   600: training accuracy 0.78
# Step   700: training accuracy 0.83
# Step   800: training accuracy 0.88
# Step   900: training accuracy 0.81
# Step  1000: training accuracy 0.8
# Step  1100: training accuracy 0.82
# Step  1200: training accuracy 0.86
# Step  1300: training accuracy 0.88
# Step  1400: training accuracy 0.87
# Step  1500: training accuracy 0.87
# Step  1600: training accuracy 0.87
# Step  1700: training accuracy 0.87
# Step  1800: training accuracy 0.89
# Step  1900: training accuracy 0.88
# Step  2000: training accuracy 0.83
# Step  2100: training accuracy 0.8
# Step  2200: training accuracy 0.87
# Step  2300: training accuracy 0.92
# Step  2400: training accuracy 0.88
# Step  2500: training accuracy 0.88
# Step  2600: training accuracy 0.86
# Step  2700: training accuracy 0.84
# Step  2800: training accuracy 0.85
# Step  2900: training accuracy 0.84
# Step  3000: training accuracy 0.85
# Step  3100: training accuracy 0.86
# Step  3200: training accuracy 0.81
# Step  3300: training accuracy 0.87
# Step  3400: training accuracy 0.89
# Step  3500: training accuracy 0.88
# Step  3600: training accuracy 0.82
# Step  3700: training accuracy 0.87
# Step  3800: training accuracy 0.89
# Step  3900: training accuracy 0.81
# Step  4000: training accuracy 0.85
# Step  4100: training accuracy 0.9
# Step  4200: training accuracy 0.83
# Step  4300: training accuracy 0.84
# Step  4400: training accuracy 0.92
# Step  4500: training accuracy 0.83
# Step  4600: training accuracy 0.86
# Step  4700: training accuracy 0.82
# Step  4800: training accuracy 0.92
# Step  4900: training accuracy 0.85
# Step  5000: training accuracy 0.89
# Step  5100: training accuracy 0.79
# Step  5200: training accuracy 0.83
# Step  5300: training accuracy 0.83
# Step  5400: training accuracy 0.89
# Step  5500: training accuracy 0.9
# Step  5600: training accuracy 0.87
# Step  5700: training accuracy 0.83
# Step  5800: training accuracy 0.87
# Step  5900: training accuracy 0.86
# Step  6000: training accuracy 0.84
# Step  6100: training accuracy 0.84
# Step  6200: training accuracy 0.94
# Step  6300: training accuracy 0.86
# Step  6400: training accuracy 0.89
# Step  6500: training accuracy 0.88
# Step  6600: training accuracy 0.89
# Step  6700: training accuracy 0.87
# Step  6800: training accuracy 0.92
# Step  6900: training accuracy 0.9
# Step  7000: training accuracy 0.91
# Step  7100: training accuracy 0.83
# Step  7200: training accuracy 0.87
# Step  7300: training accuracy 0.88
# Step  7400: training accuracy 0.89
# Step  7500: training accuracy 0.93
# Step  7600: training accuracy 0.91
# Step  7700: training accuracy 0.87
# Step  7800: training accuracy 0.87
# Step  7900: training accuracy 0.91
# Step  8000: training accuracy 0.87
# Step  8100: training accuracy 0.85
# Step  8200: training accuracy 0.92
# Step  8300: training accuracy 0.86
# Step  8400: training accuracy 0.87
# Step  8500: training accuracy 0.87
# Step  8600: training accuracy 0.86
# Step  8700: training accuracy 0.86
# Step  8800: training accuracy 0.84
# Step  8900: training accuracy 0.96
# Step  9000: training accuracy 0.94
# Step  9100: training accuracy 0.87
# Step  9200: training accuracy 0.91
# Step  9300: training accuracy 0.89
# Step  9400: training accuracy 0.9
# Step  9500: training accuracy 0.87
# Step  9600: training accuracy 0.8
# Step  9700: training accuracy 0.89
# Step  9800: training accuracy 0.92
# Step  9900: training accuracy 0.88
# Test accuracy 0.901
